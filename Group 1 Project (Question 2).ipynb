# %%
# Load libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
import seaborn as sns
from scipy import interp

from collections import Counter
from imblearn.over_sampling import ADASYN, SMOTE, RandomOverSampler
from imblearn.pipeline import make_pipeline
from imblearn.combine import SMOTEENN, SMOTETomek

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score 
from sklearn.feature_selection import RFECV
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC

import pandas_profiling as pp
from pycaret.classification import *

# %%
# Load dataset
bm = pd.read_csv("bank_marketing_scikit_label_dataset.csv")

# %%
# Change the unit of "duration" from seconds to minutes
bm['duration'] = bm['duration'].apply(lambda n: n / 60).round(2)

# Drop rows with "duration" < 5s because those interactions do not contribute much
duration_condition = (bm['duration'] < 5 / 60)
bm = bm.drop(bm[duration_condition].index, axis=0, inplace=False)

# Drop rows with "job" or "education" == "unknown"
job_condition = (bm['job'] == 11.0)
bm = bm.drop(bm[job_condition].index, axis=0, inplace=False)
edu_condition = (bm['education'] == 3.0)
bm = bm.drop(bm[edu_condition].index, axis=0, inplace=False)

# %%
# Change the types of the target classifier columns

bm["response"] = bm['y'].astype('category')
bm["response"].describe()
bm = bm.drop('y', axis=1)

bm["credit_default"] = bm['default'].astype('category')
bm["credit_default"].describe()
bm = bm.drop('default', axis=1)

bm["personal_loan"] = bm['loan'].astype('category')
bm["personal_loan"].describe()
bm = bm.drop('loan', axis=1)

# %%
bm.head(5)
# Out:
#     age   job  marital  education  balance  housing  contact   day  month  \
# 0  30.0  10.0      1.0        0.0   1787.0      0.0      0.0  19.0   10.0
# 1  33.0   7.0      1.0        1.0   4789.0      1.0      0.0  11.0    8.0
# 2  35.0   4.0      2.0        2.0   1350.0      1.0      0.0  16.0    0.0
# 3  30.0   4.0      1.0        2.0   1476.0      1.0      2.0   3.0    6.0
# 4  59.0   1.0      1.0        1.0      0.0      1.0      2.0   5.0    8.0
#
#    duration  campaign  pdays  previous  poutcome response credit_default  \
# 0      1.32       1.0   -1.0       0.0       3.0      0.0            0.0
# 1      3.67       1.0  339.0       4.0       0.0      0.0            0.0
# 2      3.08       1.0  330.0       1.0       0.0      0.0            0.0
# 3      3.32       4.0   -1.0       0.0       3.0      0.0            0.0
# 4      3.77       1.0   -1.0       0.0       3.0      0.0            0.0
#
#   personal_loan
# 0           0.0
# 1           1.0
# 2           0.0
# 3           1.0
# 4           0.0

# %%
bm["month"].value_counts()
# Out:
# 8.0     1336
# 5.0      675
# 1.0      611
# 6.0      491
# 9.0      375
# 0.0      286
# 3.0      212
# 4.0      134
# 10.0      72
# 7.0       46
# 11.0      45
# 2.0       18
# Name: month, dtype: int64

# %% [markdown]
# ### Check Imbalance Issues

# %%
# Check the imbalance problem in "default"
bm.credit_default.value_counts().plot(kind='bar', title='Count(credit_default)')

# %% [markdown]
# From the above bar graph of the "credit_default" column, the "1" or "yes" class is even more dramatically less than the "0" or "no" class with only 73 "yes" and 4228 "no".

# %% [markdown]
# ### Testing Stratified Sampling
#
# To address and try to solve the class imbalance issue, we first test the effectiveness of using stratified sampling alone. The testing algorithm in this case is the Gaussian NB model.
#
# Before the actual testing, we need to set up the different sets of X (predictor sets) and y (target) since our three research questions are targeting different predictors.

# %%
# Set up X and y for the second question
X2 = bm.drop((['credit_default']), axis=1)
y2 = bm['credit_default']
X2 = X2.astype('int')
y2 = y2.astype('category')

# %%
# Specify metrics used for performance evaluation
metric_names = ['f1', 'roc_auc', 'average_precision', 'accuracy', 'precision', 'recall']

scores_df = pd.DataFrame(index=metric_names, columns=['Random-CV', 'Stratified-CV'])

# Set up a 10-fold CV to compare with the stratified approach
cv = KFold(n_splits=10)
scv = StratifiedKFold(n_splits=10)
clf = GaussianNB() # trial run with basic algorithm

# %%
# Trial testing performance comparison for "credit_default" target
for metric in metric_names:
    score1 = cross_val_score(clf, X2, y2, scoring=metric, cv=cv).mean()
    score2 = cross_val_score(clf, X2, y2, scoring=metric, cv=scv).mean()
    scores_df.loc[metric] = [score1, score2]

scores_df
# Out:
#                    Random-CV Stratified-CV
# f1                 0.0714398     0.0776615
# roc_auc             0.738576      0.745832
# average_precision   0.111137      0.106195
# accuracy            0.889341      0.892364
# precision          0.0435773     0.0464738
# recall              0.237424      0.255357

# %% [markdown]
# ### Resampling

# %% [markdown]
# #### Setting Up Before Oversampling
#
# Here we set up the stratified 10-fold CV and a list of models (not yet tuned) that we will use for testing the effectiveness of several oversampling methods.

# %%
RANSTA = 50

scv = StratifiedKFold(n_splits=10, random_state=RANSTA, shuffle=True)

models = []
models.append((LogisticRegression(solver='lbfgs', max_iter=7000)))
models.append((KNeighborsClassifier(n_neighbors=5)))
models.append((DecisionTreeClassifier()))
models.append((RandomForestClassifier()))
models.append((GaussianNB()))
models.append((SVC()))

# %% [markdown]
# To make the oversampling method testing process more succinct and easy to read, we first create a helper function using for loops to evaluate the list of models and print out the metrics table.

# %%
def oversampleReport(models, metric_names, X_resampled, y_resampled):
  """
  Print model and metrics report table
  """
  scores_cols = ['LR', 'KNN', 'DT', 'RF', 'NB', 'SVC']
  scores = pd.DataFrame(index=metric_names, columns=scores_cols)

  for key, model in enumerate(models):
      for metric in metric_names:
          score = cross_val_score(model, X_resampled, y_resampled, scoring=metric, cv=scv).mean()
          scores.at[metric, scores_cols[key]] = score 
  
  return scores

# %% [markdown]
# #### Oversampling Only (SMOTE and ADASYN)
#
# To perform oversampling, we start by using one of the most known techniques: SMOTE (Synthetic Minority Over-sampling Technique). This method create synthetic datapoints in the following steps:
#
# 1. For each real/existing data point, seek for its K nearest neighbors (default K = 5)
# 2. Randomly choose one of the neighbors and build a vector between the two points
# 3. Multiplying the vector with a random number between one and zero to get the new data point.
#
# The Adaptive Synthetic (ADASYN) is an adaptive approach of SMOTE.
#
# SMOTE: https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-14-106
#
# ADASYN: https://www.researchgate.net/publication/224330873_ADASYN_Adaptive_Synthetic_Sampling_Approach_for_Imbalanced_Learning

# %% [markdown]
# ##### SMOTE

# %%
# SMOTE oversampling for the second question
smote = SMOTE(random_state=RANSTA)
X_resampled_s2, y_resampled_s2 = smote.fit_resample(X2, y2)

# Check the number of observations in each class after resampling
print(sorted(Counter(y_resampled_s2).items()))

oversampleReport(models, metric_names, X_resampled_s2, y_resampled_s2)
# Out:
# [(0.0, 4228), (1.0, 4228)]
#                          LR       KNN        DT        RF        NB       SVC
# f1                 0.872199  0.909313  0.966076  0.986028  0.757729  0.802922
# roc_auc            0.939446  0.959008  0.966886  0.999256  0.879959  0.881599
# average_precision  0.927933  0.933417  0.942275  0.999261  0.890549  0.849965
# accuracy           0.868497   0.90374  0.967718  0.986047  0.713455  0.774009
# precision          0.848764   0.85998  0.952461  0.978407  0.656538  0.712633
# recall             0.897352  0.964763  0.980367  0.991958   0.89593  0.919819

# %% [markdown]
# ##### ADASYN

# %%
# ADASYN oversampling for the second question
ada = ADASYN(random_state=RANSTA)
X_resampled_a2, y_resampled_a2 = ada.fit_resample(X2, y2)

# Check the number of observations in each class after resampling
print(sorted(Counter(y_resampled_a2).items()))

oversampleReport(models, metric_names, X_resampled_a2, y_resampled_a2)
# Out:
# [(0.0, 4228), (1.0, 4201)]
#                          LR       KNN        DT        RF        NB       SVC
# f1                 0.862211  0.906667  0.965984  0.985351  0.756899  0.795547
# roc_auc            0.934711  0.958066  0.966008  0.999076  0.879687  0.871969
# average_precision  0.922035  0.930649  0.943762  0.999177  0.890155  0.837367
# accuracy           0.859176  0.901056  0.966663  0.986238  0.714556  0.765691
# precision          0.842075  0.856257  0.950257  0.977572  0.657807  0.704618
# recall             0.883595  0.963581  0.983812  0.992382  0.891452  0.913831

# %% [markdown]
# #### Combination of Over- and Undersampling (SMOTETomek and SMOTEENN)
#
# In addition to using oversampling by itself, we also decided to test the combination methods which consist of both oversampling and undersampling techniques. Since SMOTE generates samples without regards to the underlying distribution, it might create some noisy samples where the two classes have no clear distinction. In this case, implementing undersampling algorithms such as Tomek's link and Edited Nearest Neighbors can be good for cleaning noisy samples.
#
# Tomek's link: https://dl.acm.org/doi/10.1145/1007730.1007735
#
# ENN: https://pdfs.semanticscholar.org/c1a9/5197e15fa99f55cd0cb2ee14d2f02699a919.pdf
#
# The imbalanced-learn library has implemented these two algorithms in combination with SMOTE to create two useful classes: SMOTETomek and SMOTEENN.

# %% [markdown]
# ##### SMOTETomek

# %%
# SMOTETomek combo for the second question
smo_tmk = SMOTETomek(random_state=RANSTA)
X_resampled_st2, y_resampled_st2 = smo_tmk.fit_resample(X2, y2)

# Check the number of observations in each class after resampling
print(sorted(Counter(y_resampled_st2).items()))

oversampleReport(models, metric_names, X_resampled_st2, y_resampled_st2)
# Out:
# [(0.0, 4168), (1.0, 4168)]
#                          LR       KNN        DT        RF        NB       SVC
# f1                 0.874725  0.914505  0.968441  0.985109  0.759403  0.807068
# roc_auc            0.941787  0.963648  0.966409  0.999208  0.882597  0.885642
# average_precision  0.931593  0.939372   0.94682  0.999223    0.8927    0.8538
# accuracy           0.871042  0.909188  0.969649  0.985725  0.716052  0.779153
# precision          0.851019  0.864199  0.954924  0.978491  0.658947   0.71665
# recall              0.89995  0.971206  0.980565  0.990883  0.896114  0.923703

# %% [markdown]
# ##### SMOTEENN

# %%
# SMOTE-ENN combo for the second question
smo_enn = SMOTEENN(random_state=RANSTA)
X_resampled_se2, y_resampled_se2 = smo_enn.fit_resample(X2, y2)

# Check the number of observations in each class after resampling
print(sorted(Counter(y_resampled_se2).items()))

oversampleReport(models, metric_names, X_resampled_se2, y_resampled_se2)
# Out:
# [(0.0, 3203), (1.0, 3953)]
#                          LR       KNN        DT        RF        NB       SVC
# f1                 0.921041  0.978041  0.980163  0.990794  0.817287      0.87
# roc_auc            0.968369  0.995917  0.973821  0.999522  0.911581  0.933683
# average_precision  0.970939   0.99381  0.966633  0.999681  0.933043  0.935213
# accuracy           0.910563  0.975267  0.976385   0.98938  0.776692  0.844747
# precision          0.898929  0.961047  0.973865  0.989183  0.745844  0.809649
# recall             0.944341  0.995702  0.986847  0.993423  0.904123  0.940299

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# #### Train-Test Split (Using Resampled Data)

# %%
# train-test 80/20 split for "credit_default" classification
X2_train, X2_test, y2_train, y2_test = train_test_split(X_resampled_se2, y_resampled_se2, test_size=0.2, random_state=RANSTA)

# %%
cv_estimator = RandomForestClassifier(n_jobs=4, random_state=RANSTA)
cv_estimator.fit(X2_train, y2_train)
cv_selector = RFECV(cv_estimator,cv= 10, step=1,scoring='accuracy')
cv_selector = cv_selector.fit(X2_train, y2_train)
rfecv_mask = cv_selector.get_support()

rfecv_features = []

for bool, feature in zip(rfecv_mask, X2_train.columns):
    if bool:
        rfecv_features.append(feature)

print('Optimal number of features :', cv_selector.n_features_)
print('Best features :', rfecv_features)
n_features = X2_train.shape[1]
plt.figure(figsize=(8,8))
plt.barh(range(n_features), cv_estimator.feature_importances_, align='center') 
plt.yticks(np.arange(n_features), X2_train.columns.values) 
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()
# Out:
# Optimal number of features : 16
# Best features : ['age', 'job', 'marital', 'education', 'balance', 'housing', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'response', 'personal_loan']

# %% [markdown]
# ### Further Modeling

# %%
def hyperTuning(model, param_grid, X_train, y_train, X_test, y_test):
  """
  @params model: ML model, scikit-learn object
  @params param_grid: the hyperparameter for the model
  @return best training model (cross-validated)
  """
  grid_search = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=10, scoring='accuracy',error_score=0)
  grid_result = grid_search.fit(X_train, y_train)
  # summarize results
  
  means = grid_result.cv_results_['mean_test_score']
  stds = grid_result.cv_results_['std_test_score']
  params = grid_result.cv_results_['params']
  for mean, stdev, param in zip(means, stds, params):
      print("%f (%f) with: %r" % (mean, stdev, param))

  print("-----------------------------------------------------------")
  print()
  print("Best Accuracy: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
  print()

  y_true, y_pred = y_test, grid_result.predict(X_test)
  print("Detailed classification report:")
  print()
  print(classification_report(y_true, y_pred))

# %% [markdown]
# ### ROC Curve Before Tuning

# %%
classifiers = [LogisticRegression(random_state=RANSTA), 
               KNeighborsClassifier(), 
               RandomForestClassifier(random_state=RANSTA)]

# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    model = cls.fit(X2_train, y2_train)
    yproba = model.predict_proba(X2_test)[::,1]
    
    fpr, tpr, _ = roc_curve(y2_test,  yproba)
    auc = roc_auc_score(y2_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)

fig = plt.figure(figsize=(8,6))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()
# Out:
# C:\Users\devil\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# #### KNN

# %%
hyperTuning(KNeighborsClassifier(), 
            dict(leaf_size=list(range(1,50)), n_neighbors=list(range(1,30)), p=[1,2]),
            X2_train, y2_train, X2_test, y2_test)
# Out:
# 0.990041 (0.003753) with: {'leaf_size': 1, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 1, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 1, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 1, 'n_neighbors': 2, 'p': 2}
# 0.977811 (0.007461) with: {'leaf_size': 1, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 1, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006213) with: {'leaf_size': 1, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 1, 'n_neighbors': 4, 'p': 2}
# 0.972047 (0.005746) with: {'leaf_size': 1, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008810) with: {'leaf_size': 1, 'n_neighbors': 5, 'p': 2}
# 0.972920 (0.005912) with: {'leaf_size': 1, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 1, 'n_neighbors': 6, 'p': 2}
# 0.963834 (0.007785) with: {'leaf_size': 1, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 1, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.006869) with: {'leaf_size': 1, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 1, 'n_neighbors': 8, 'p': 2}
# 0.959293 (0.007586) with: {'leaf_size': 1, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 1, 'n_neighbors': 9, 'p': 2}
# 0.960691 (0.007132) with: {'leaf_size': 1, 'n_neighbors': 10, 'p': 1}
# 0.956497 (0.008295) with: {'leaf_size': 1, 'n_neighbors': 10, 'p': 2}
# 0.954402 (0.006375) with: {'leaf_size': 1, 'n_neighbors': 11, 'p': 1}
# 0.950730 (0.009453) with: {'leaf_size': 1, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005874) with: {'leaf_size': 1, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 1, 'n_neighbors': 12, 'p': 2}
# 0.949859 (0.007824) with: {'leaf_size': 1, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 1, 'n_neighbors': 13, 'p': 2}
# 0.949336 (0.008670) with: {'leaf_size': 1, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 1, 'n_neighbors': 14, 'p': 2}
# 0.945667 (0.008655) with: {'leaf_size': 1, 'n_neighbors': 15, 'p': 1}
# 0.943045 (0.009593) with: {'leaf_size': 1, 'n_neighbors': 15, 'p': 2}
# 0.947590 (0.009011) with: {'leaf_size': 1, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 1, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.008954) with: {'leaf_size': 1, 'n_neighbors': 17, 'p': 1}
# 0.939726 (0.009199) with: {'leaf_size': 1, 'n_neighbors': 17, 'p': 2}
# 0.946018 (0.010078) with: {'leaf_size': 1, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 1, 'n_neighbors': 18, 'p': 2}
# 0.940427 (0.010376) with: {'leaf_size': 1, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 1, 'n_neighbors': 19, 'p': 2}
# 0.941651 (0.008974) with: {'leaf_size': 1, 'n_neighbors': 20, 'p': 1}
# 0.938854 (0.007898) with: {'leaf_size': 1, 'n_neighbors': 20, 'p': 2}
# 0.937806 (0.010777) with: {'leaf_size': 1, 'n_neighbors': 21, 'p': 1}
# 0.934312 (0.007700) with: {'leaf_size': 1, 'n_neighbors': 21, 'p': 2}
# 0.939029 (0.008058) with: {'leaf_size': 1, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 1, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.008773) with: {'leaf_size': 1, 'n_neighbors': 23, 'p': 1}
# 0.933089 (0.008772) with: {'leaf_size': 1, 'n_neighbors': 23, 'p': 2}
# 0.936758 (0.008758) with: {'leaf_size': 1, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 1, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009141) with: {'leaf_size': 1, 'n_neighbors': 25, 'p': 1}
# 0.930468 (0.009370) with: {'leaf_size': 1, 'n_neighbors': 25, 'p': 2}
# 0.933964 (0.009900) with: {'leaf_size': 1, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 1, 'n_neighbors': 26, 'p': 2}
# 0.931343 (0.009140) with: {'leaf_size': 1, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 1, 'n_neighbors': 27, 'p': 2}
# 0.931868 (0.009360) with: {'leaf_size': 1, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 1, 'n_neighbors': 28, 'p': 2}
# 0.929422 (0.010213) with: {'leaf_size': 1, 'n_neighbors': 29, 'p': 1}
# 0.926974 (0.009790) with: {'leaf_size': 1, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 2, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 2, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 2, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 2, 'n_neighbors': 2, 'p': 2}
# 0.977811 (0.007419) with: {'leaf_size': 2, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 2, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006213) with: {'leaf_size': 2, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 2, 'n_neighbors': 4, 'p': 2}
# 0.972221 (0.005718) with: {'leaf_size': 2, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 2, 'n_neighbors': 5, 'p': 2}
# 0.972571 (0.006056) with: {'leaf_size': 2, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 2, 'n_neighbors': 6, 'p': 2}
# 0.964009 (0.007136) with: {'leaf_size': 2, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 2, 'n_neighbors': 7, 'p': 2}
# 0.967503 (0.007222) with: {'leaf_size': 2, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 2, 'n_neighbors': 8, 'p': 2}
# 0.959642 (0.007272) with: {'leaf_size': 2, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 2, 'n_neighbors': 9, 'p': 2}
# 0.961041 (0.006908) with: {'leaf_size': 2, 'n_neighbors': 10, 'p': 1}
# 0.956322 (0.008533) with: {'leaf_size': 2, 'n_neighbors': 10, 'p': 2}
# 0.954402 (0.006515) with: {'leaf_size': 2, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 2, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005980) with: {'leaf_size': 2, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 2, 'n_neighbors': 12, 'p': 2}
# 0.949160 (0.008442) with: {'leaf_size': 2, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 2, 'n_neighbors': 13, 'p': 2}
# 0.949336 (0.008311) with: {'leaf_size': 2, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 2, 'n_neighbors': 14, 'p': 2}
# 0.945842 (0.008706) with: {'leaf_size': 2, 'n_neighbors': 15, 'p': 1}
# 0.943045 (0.009593) with: {'leaf_size': 2, 'n_neighbors': 15, 'p': 2}
# 0.947589 (0.009013) with: {'leaf_size': 2, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 2, 'n_neighbors': 16, 'p': 2}
# 0.942523 (0.009487) with: {'leaf_size': 2, 'n_neighbors': 17, 'p': 1}
# 0.939901 (0.009330) with: {'leaf_size': 2, 'n_neighbors': 17, 'p': 2}
# 0.945495 (0.010146) with: {'leaf_size': 2, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.009964) with: {'leaf_size': 2, 'n_neighbors': 18, 'p': 2}
# 0.939903 (0.009636) with: {'leaf_size': 2, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 2, 'n_neighbors': 19, 'p': 2}
# 0.942175 (0.008706) with: {'leaf_size': 2, 'n_neighbors': 20, 'p': 1}
# 0.938854 (0.007898) with: {'leaf_size': 2, 'n_neighbors': 20, 'p': 2}
# 0.938679 (0.009583) with: {'leaf_size': 2, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 2, 'n_neighbors': 21, 'p': 2}
# 0.939204 (0.007996) with: {'leaf_size': 2, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 2, 'n_neighbors': 22, 'p': 2}
# 0.936584 (0.008803) with: {'leaf_size': 2, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 2, 'n_neighbors': 23, 'p': 2}
# 0.936759 (0.008860) with: {'leaf_size': 2, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 2, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009371) with: {'leaf_size': 2, 'n_neighbors': 25, 'p': 1}
# 0.930643 (0.009444) with: {'leaf_size': 2, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009635) with: {'leaf_size': 2, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 2, 'n_neighbors': 26, 'p': 2}
# 0.931168 (0.009079) with: {'leaf_size': 2, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 2, 'n_neighbors': 27, 'p': 2}
# 0.931344 (0.009523) with: {'leaf_size': 2, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 2, 'n_neighbors': 28, 'p': 2}
# 0.929247 (0.010095) with: {'leaf_size': 2, 'n_neighbors': 29, 'p': 1}
# 0.927148 (0.009922) with: {'leaf_size': 2, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 3, 'n_neighbors': 1, 'p': 1}
# 0.991265 (0.004815) with: {'leaf_size': 3, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 3, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 3, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 3, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 3, 'n_neighbors': 3, 'p': 2}
# 0.981656 (0.006066) with: {'leaf_size': 3, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 3, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006375) with: {'leaf_size': 3, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 3, 'n_neighbors': 5, 'p': 2}
# 0.972746 (0.005754) with: {'leaf_size': 3, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 3, 'n_neighbors': 6, 'p': 2}
# 0.964009 (0.007389) with: {'leaf_size': 3, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 3, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.006869) with: {'leaf_size': 3, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 3, 'n_neighbors': 8, 'p': 2}
# 0.959118 (0.007588) with: {'leaf_size': 3, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 3, 'n_neighbors': 9, 'p': 2}
# 0.960691 (0.007091) with: {'leaf_size': 3, 'n_neighbors': 10, 'p': 1}
# 0.956497 (0.008295) with: {'leaf_size': 3, 'n_neighbors': 10, 'p': 2}
# 0.954577 (0.006770) with: {'leaf_size': 3, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 3, 'n_neighbors': 11, 'p': 2}
# 0.956498 (0.005770) with: {'leaf_size': 3, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 3, 'n_neighbors': 12, 'p': 2}
# 0.949160 (0.008147) with: {'leaf_size': 3, 'n_neighbors': 13, 'p': 1}
# 0.947935 (0.010641) with: {'leaf_size': 3, 'n_neighbors': 13, 'p': 2}
# 0.949686 (0.008482) with: {'leaf_size': 3, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 3, 'n_neighbors': 14, 'p': 2}
# 0.945142 (0.008647) with: {'leaf_size': 3, 'n_neighbors': 15, 'p': 1}
# 0.942695 (0.009483) with: {'leaf_size': 3, 'n_neighbors': 15, 'p': 2}
# 0.947590 (0.009474) with: {'leaf_size': 3, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 3, 'n_neighbors': 16, 'p': 2}
# 0.942698 (0.008867) with: {'leaf_size': 3, 'n_neighbors': 17, 'p': 1}
# 0.939901 (0.009330) with: {'leaf_size': 3, 'n_neighbors': 17, 'p': 2}
# 0.944795 (0.010190) with: {'leaf_size': 3, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 3, 'n_neighbors': 18, 'p': 2}
# 0.940078 (0.009535) with: {'leaf_size': 3, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 3, 'n_neighbors': 19, 'p': 2}
# 0.942350 (0.009494) with: {'leaf_size': 3, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 3, 'n_neighbors': 20, 'p': 2}
# 0.938155 (0.009922) with: {'leaf_size': 3, 'n_neighbors': 21, 'p': 1}
# 0.934661 (0.007743) with: {'leaf_size': 3, 'n_neighbors': 21, 'p': 2}
# 0.939204 (0.008186) with: {'leaf_size': 3, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 3, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.009014) with: {'leaf_size': 3, 'n_neighbors': 23, 'p': 1}
# 0.933089 (0.008772) with: {'leaf_size': 3, 'n_neighbors': 23, 'p': 2}
# 0.936584 (0.008904) with: {'leaf_size': 3, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 3, 'n_neighbors': 24, 'p': 2}
# 0.933265 (0.009587) with: {'leaf_size': 3, 'n_neighbors': 25, 'p': 1}
# 0.930294 (0.009193) with: {'leaf_size': 3, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009698) with: {'leaf_size': 3, 'n_neighbors': 26, 'p': 1}
# 0.931167 (0.009605) with: {'leaf_size': 3, 'n_neighbors': 26, 'p': 2}
# 0.930819 (0.008974) with: {'leaf_size': 3, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 3, 'n_neighbors': 27, 'p': 2}
# 0.931519 (0.009352) with: {'leaf_size': 3, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 3, 'n_neighbors': 28, 'p': 2}
# 0.928897 (0.009752) with: {'leaf_size': 3, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 3, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 4, 'n_neighbors': 1, 'p': 1}
# 0.991265 (0.004815) with: {'leaf_size': 4, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 4, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 4, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 4, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 4, 'n_neighbors': 3, 'p': 2}
# 0.981656 (0.006066) with: {'leaf_size': 4, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 4, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006375) with: {'leaf_size': 4, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 4, 'n_neighbors': 5, 'p': 2}
# 0.972746 (0.005754) with: {'leaf_size': 4, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 4, 'n_neighbors': 6, 'p': 2}
# 0.964009 (0.007389) with: {'leaf_size': 4, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 4, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.006869) with: {'leaf_size': 4, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 4, 'n_neighbors': 8, 'p': 2}
# 0.959118 (0.007588) with: {'leaf_size': 4, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 4, 'n_neighbors': 9, 'p': 2}
# 0.960691 (0.007091) with: {'leaf_size': 4, 'n_neighbors': 10, 'p': 1}
# 0.956497 (0.008295) with: {'leaf_size': 4, 'n_neighbors': 10, 'p': 2}
# 0.954577 (0.006770) with: {'leaf_size': 4, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 4, 'n_neighbors': 11, 'p': 2}
# 0.956498 (0.005770) with: {'leaf_size': 4, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 4, 'n_neighbors': 12, 'p': 2}
# 0.949160 (0.008147) with: {'leaf_size': 4, 'n_neighbors': 13, 'p': 1}
# 0.947935 (0.010641) with: {'leaf_size': 4, 'n_neighbors': 13, 'p': 2}
# 0.949686 (0.008482) with: {'leaf_size': 4, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 4, 'n_neighbors': 14, 'p': 2}
# 0.945142 (0.008647) with: {'leaf_size': 4, 'n_neighbors': 15, 'p': 1}
# 0.942695 (0.009483) with: {'leaf_size': 4, 'n_neighbors': 15, 'p': 2}
# 0.947590 (0.009474) with: {'leaf_size': 4, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 4, 'n_neighbors': 16, 'p': 2}
# 0.942698 (0.008867) with: {'leaf_size': 4, 'n_neighbors': 17, 'p': 1}
# 0.939901 (0.009330) with: {'leaf_size': 4, 'n_neighbors': 17, 'p': 2}
# 0.944795 (0.010190) with: {'leaf_size': 4, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 4, 'n_neighbors': 18, 'p': 2}
# 0.940078 (0.009535) with: {'leaf_size': 4, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 4, 'n_neighbors': 19, 'p': 2}
# 0.942350 (0.009494) with: {'leaf_size': 4, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 4, 'n_neighbors': 20, 'p': 2}
# 0.938155 (0.009922) with: {'leaf_size': 4, 'n_neighbors': 21, 'p': 1}
# 0.934661 (0.007743) with: {'leaf_size': 4, 'n_neighbors': 21, 'p': 2}
# 0.939204 (0.008186) with: {'leaf_size': 4, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 4, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.009014) with: {'leaf_size': 4, 'n_neighbors': 23, 'p': 1}
# 0.933089 (0.008772) with: {'leaf_size': 4, 'n_neighbors': 23, 'p': 2}
# 0.936584 (0.008904) with: {'leaf_size': 4, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 4, 'n_neighbors': 24, 'p': 2}
# 0.933265 (0.009587) with: {'leaf_size': 4, 'n_neighbors': 25, 'p': 1}
# 0.930294 (0.009193) with: {'leaf_size': 4, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009698) with: {'leaf_size': 4, 'n_neighbors': 26, 'p': 1}
# 0.931167 (0.009605) with: {'leaf_size': 4, 'n_neighbors': 26, 'p': 2}
# 0.930819 (0.008974) with: {'leaf_size': 4, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 4, 'n_neighbors': 27, 'p': 2}
# 0.931519 (0.009352) with: {'leaf_size': 4, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 4, 'n_neighbors': 28, 'p': 2}
# 0.928897 (0.009752) with: {'leaf_size': 4, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 4, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 5, 'n_neighbors': 1, 'p': 1}
# 0.991265 (0.004815) with: {'leaf_size': 5, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 5, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 5, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 5, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 5, 'n_neighbors': 3, 'p': 2}
# 0.981656 (0.006066) with: {'leaf_size': 5, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 5, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006375) with: {'leaf_size': 5, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 5, 'n_neighbors': 5, 'p': 2}
# 0.972746 (0.005754) with: {'leaf_size': 5, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 5, 'n_neighbors': 6, 'p': 2}
# 0.964009 (0.007389) with: {'leaf_size': 5, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 5, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.006869) with: {'leaf_size': 5, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 5, 'n_neighbors': 8, 'p': 2}
# 0.959118 (0.007588) with: {'leaf_size': 5, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 5, 'n_neighbors': 9, 'p': 2}
# 0.960691 (0.007091) with: {'leaf_size': 5, 'n_neighbors': 10, 'p': 1}
# 0.956497 (0.008295) with: {'leaf_size': 5, 'n_neighbors': 10, 'p': 2}
# 0.954577 (0.006770) with: {'leaf_size': 5, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 5, 'n_neighbors': 11, 'p': 2}
# 0.956498 (0.005770) with: {'leaf_size': 5, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 5, 'n_neighbors': 12, 'p': 2}
# 0.949160 (0.008147) with: {'leaf_size': 5, 'n_neighbors': 13, 'p': 1}
# 0.947935 (0.010641) with: {'leaf_size': 5, 'n_neighbors': 13, 'p': 2}
# 0.949686 (0.008482) with: {'leaf_size': 5, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 5, 'n_neighbors': 14, 'p': 2}
# 0.945142 (0.008647) with: {'leaf_size': 5, 'n_neighbors': 15, 'p': 1}
# 0.942695 (0.009483) with: {'leaf_size': 5, 'n_neighbors': 15, 'p': 2}
# 0.947590 (0.009474) with: {'leaf_size': 5, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 5, 'n_neighbors': 16, 'p': 2}
# 0.942698 (0.008867) with: {'leaf_size': 5, 'n_neighbors': 17, 'p': 1}
# 0.939901 (0.009330) with: {'leaf_size': 5, 'n_neighbors': 17, 'p': 2}
# 0.944795 (0.010190) with: {'leaf_size': 5, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 5, 'n_neighbors': 18, 'p': 2}
# 0.940078 (0.009535) with: {'leaf_size': 5, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 5, 'n_neighbors': 19, 'p': 2}
# 0.942350 (0.009494) with: {'leaf_size': 5, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 5, 'n_neighbors': 20, 'p': 2}
# 0.938155 (0.009922) with: {'leaf_size': 5, 'n_neighbors': 21, 'p': 1}
# 0.934661 (0.007743) with: {'leaf_size': 5, 'n_neighbors': 21, 'p': 2}
# 0.939204 (0.008186) with: {'leaf_size': 5, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 5, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.009014) with: {'leaf_size': 5, 'n_neighbors': 23, 'p': 1}
# 0.933089 (0.008772) with: {'leaf_size': 5, 'n_neighbors': 23, 'p': 2}
# 0.936584 (0.008904) with: {'leaf_size': 5, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 5, 'n_neighbors': 24, 'p': 2}
# 0.933265 (0.009587) with: {'leaf_size': 5, 'n_neighbors': 25, 'p': 1}
# 0.930294 (0.009193) with: {'leaf_size': 5, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009698) with: {'leaf_size': 5, 'n_neighbors': 26, 'p': 1}
# 0.931167 (0.009605) with: {'leaf_size': 5, 'n_neighbors': 26, 'p': 2}
# 0.930819 (0.008974) with: {'leaf_size': 5, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 5, 'n_neighbors': 27, 'p': 2}
# 0.931519 (0.009352) with: {'leaf_size': 5, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 5, 'n_neighbors': 28, 'p': 2}
# 0.928897 (0.009752) with: {'leaf_size': 5, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 5, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 6, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 6, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 6, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 6, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 6, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 6, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006406) with: {'leaf_size': 6, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 6, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006030) with: {'leaf_size': 6, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 6, 'n_neighbors': 5, 'p': 2}
# 0.973095 (0.005961) with: {'leaf_size': 6, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 6, 'n_neighbors': 6, 'p': 2}
# 0.964183 (0.007636) with: {'leaf_size': 6, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 6, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.007423) with: {'leaf_size': 6, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 6, 'n_neighbors': 8, 'p': 2}
# 0.959642 (0.006883) with: {'leaf_size': 6, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 6, 'n_neighbors': 9, 'p': 2}
# 0.961739 (0.007059) with: {'leaf_size': 6, 'n_neighbors': 10, 'p': 1}
# 0.956322 (0.008533) with: {'leaf_size': 6, 'n_neighbors': 10, 'p': 2}
# 0.954053 (0.006256) with: {'leaf_size': 6, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 6, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005926) with: {'leaf_size': 6, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 6, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.007171) with: {'leaf_size': 6, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 6, 'n_neighbors': 13, 'p': 2}
# 0.950035 (0.008203) with: {'leaf_size': 6, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 6, 'n_neighbors': 14, 'p': 2}
# 0.945318 (0.008709) with: {'leaf_size': 6, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009650) with: {'leaf_size': 6, 'n_neighbors': 15, 'p': 2}
# 0.947589 (0.009604) with: {'leaf_size': 6, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 6, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.008645) with: {'leaf_size': 6, 'n_neighbors': 17, 'p': 1}
# 0.939551 (0.009330) with: {'leaf_size': 6, 'n_neighbors': 17, 'p': 2}
# 0.945494 (0.009718) with: {'leaf_size': 6, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 6, 'n_neighbors': 18, 'p': 2}
# 0.939903 (0.010280) with: {'leaf_size': 6, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 6, 'n_neighbors': 19, 'p': 2}
# 0.942175 (0.009509) with: {'leaf_size': 6, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 6, 'n_neighbors': 20, 'p': 2}
# 0.937631 (0.010010) with: {'leaf_size': 6, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 6, 'n_neighbors': 21, 'p': 2}
# 0.939379 (0.008768) with: {'leaf_size': 6, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 6, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.008382) with: {'leaf_size': 6, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 6, 'n_neighbors': 23, 'p': 2}
# 0.936759 (0.008615) with: {'leaf_size': 6, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 6, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009465) with: {'leaf_size': 6, 'n_neighbors': 25, 'p': 1}
# 0.930817 (0.009642) with: {'leaf_size': 6, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009727) with: {'leaf_size': 6, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 6, 'n_neighbors': 26, 'p': 2}
# 0.930294 (0.008985) with: {'leaf_size': 6, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 6, 'n_neighbors': 27, 'p': 2}
# 0.932043 (0.009724) with: {'leaf_size': 6, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 6, 'n_neighbors': 28, 'p': 2}
# 0.928898 (0.010086) with: {'leaf_size': 6, 'n_neighbors': 29, 'p': 1}
# 0.927148 (0.009922) with: {'leaf_size': 6, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 7, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 7, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 7, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 7, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 7, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 7, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006406) with: {'leaf_size': 7, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 7, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006030) with: {'leaf_size': 7, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 7, 'n_neighbors': 5, 'p': 2}
# 0.973095 (0.005961) with: {'leaf_size': 7, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 7, 'n_neighbors': 6, 'p': 2}
# 0.964183 (0.007636) with: {'leaf_size': 7, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 7, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.007423) with: {'leaf_size': 7, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 7, 'n_neighbors': 8, 'p': 2}
# 0.959642 (0.006883) with: {'leaf_size': 7, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 7, 'n_neighbors': 9, 'p': 2}
# 0.961739 (0.007059) with: {'leaf_size': 7, 'n_neighbors': 10, 'p': 1}
# 0.956322 (0.008533) with: {'leaf_size': 7, 'n_neighbors': 10, 'p': 2}
# 0.954053 (0.006256) with: {'leaf_size': 7, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 7, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005926) with: {'leaf_size': 7, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 7, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.007171) with: {'leaf_size': 7, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 7, 'n_neighbors': 13, 'p': 2}
# 0.950035 (0.008203) with: {'leaf_size': 7, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 7, 'n_neighbors': 14, 'p': 2}
# 0.945318 (0.008709) with: {'leaf_size': 7, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009650) with: {'leaf_size': 7, 'n_neighbors': 15, 'p': 2}
# 0.947589 (0.009604) with: {'leaf_size': 7, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 7, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.008645) with: {'leaf_size': 7, 'n_neighbors': 17, 'p': 1}
# 0.939551 (0.009330) with: {'leaf_size': 7, 'n_neighbors': 17, 'p': 2}
# 0.945494 (0.009718) with: {'leaf_size': 7, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 7, 'n_neighbors': 18, 'p': 2}
# 0.939903 (0.010280) with: {'leaf_size': 7, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 7, 'n_neighbors': 19, 'p': 2}
# 0.942175 (0.009509) with: {'leaf_size': 7, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 7, 'n_neighbors': 20, 'p': 2}
# 0.937631 (0.010010) with: {'leaf_size': 7, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 7, 'n_neighbors': 21, 'p': 2}
# 0.939379 (0.008768) with: {'leaf_size': 7, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 7, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.008382) with: {'leaf_size': 7, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 7, 'n_neighbors': 23, 'p': 2}
# 0.936759 (0.008615) with: {'leaf_size': 7, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 7, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009465) with: {'leaf_size': 7, 'n_neighbors': 25, 'p': 1}
# 0.930817 (0.009642) with: {'leaf_size': 7, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009727) with: {'leaf_size': 7, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 7, 'n_neighbors': 26, 'p': 2}
# 0.930294 (0.008985) with: {'leaf_size': 7, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 7, 'n_neighbors': 27, 'p': 2}
# 0.932043 (0.009724) with: {'leaf_size': 7, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 7, 'n_neighbors': 28, 'p': 2}
# 0.928898 (0.010086) with: {'leaf_size': 7, 'n_neighbors': 29, 'p': 1}
# 0.927148 (0.009922) with: {'leaf_size': 7, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 8, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 8, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 8, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 8, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 8, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 8, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006406) with: {'leaf_size': 8, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 8, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006030) with: {'leaf_size': 8, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 8, 'n_neighbors': 5, 'p': 2}
# 0.973095 (0.005961) with: {'leaf_size': 8, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 8, 'n_neighbors': 6, 'p': 2}
# 0.964183 (0.007636) with: {'leaf_size': 8, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 8, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.007423) with: {'leaf_size': 8, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 8, 'n_neighbors': 8, 'p': 2}
# 0.959642 (0.006883) with: {'leaf_size': 8, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 8, 'n_neighbors': 9, 'p': 2}
# 0.961739 (0.007059) with: {'leaf_size': 8, 'n_neighbors': 10, 'p': 1}
# 0.956322 (0.008533) with: {'leaf_size': 8, 'n_neighbors': 10, 'p': 2}
# 0.954053 (0.006256) with: {'leaf_size': 8, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 8, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005926) with: {'leaf_size': 8, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 8, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.007171) with: {'leaf_size': 8, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 8, 'n_neighbors': 13, 'p': 2}
# 0.950035 (0.008203) with: {'leaf_size': 8, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 8, 'n_neighbors': 14, 'p': 2}
# 0.945318 (0.008709) with: {'leaf_size': 8, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009650) with: {'leaf_size': 8, 'n_neighbors': 15, 'p': 2}
# 0.947589 (0.009604) with: {'leaf_size': 8, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 8, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.008645) with: {'leaf_size': 8, 'n_neighbors': 17, 'p': 1}
# 0.939551 (0.009330) with: {'leaf_size': 8, 'n_neighbors': 17, 'p': 2}
# 0.945494 (0.009718) with: {'leaf_size': 8, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 8, 'n_neighbors': 18, 'p': 2}
# 0.939903 (0.010280) with: {'leaf_size': 8, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 8, 'n_neighbors': 19, 'p': 2}
# 0.942175 (0.009509) with: {'leaf_size': 8, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 8, 'n_neighbors': 20, 'p': 2}
# 0.937631 (0.010010) with: {'leaf_size': 8, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 8, 'n_neighbors': 21, 'p': 2}
# 0.939379 (0.008768) with: {'leaf_size': 8, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 8, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.008382) with: {'leaf_size': 8, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 8, 'n_neighbors': 23, 'p': 2}
# 0.936759 (0.008615) with: {'leaf_size': 8, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 8, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009465) with: {'leaf_size': 8, 'n_neighbors': 25, 'p': 1}
# 0.930817 (0.009642) with: {'leaf_size': 8, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009727) with: {'leaf_size': 8, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 8, 'n_neighbors': 26, 'p': 2}
# 0.930294 (0.008985) with: {'leaf_size': 8, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 8, 'n_neighbors': 27, 'p': 2}
# 0.932043 (0.009724) with: {'leaf_size': 8, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 8, 'n_neighbors': 28, 'p': 2}
# 0.928898 (0.010086) with: {'leaf_size': 8, 'n_neighbors': 29, 'p': 1}
# 0.927148 (0.009922) with: {'leaf_size': 8, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 9, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 9, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 9, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 9, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 9, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 9, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006406) with: {'leaf_size': 9, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 9, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006030) with: {'leaf_size': 9, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 9, 'n_neighbors': 5, 'p': 2}
# 0.973095 (0.005961) with: {'leaf_size': 9, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 9, 'n_neighbors': 6, 'p': 2}
# 0.964183 (0.007636) with: {'leaf_size': 9, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 9, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.007423) with: {'leaf_size': 9, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 9, 'n_neighbors': 8, 'p': 2}
# 0.959642 (0.006883) with: {'leaf_size': 9, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 9, 'n_neighbors': 9, 'p': 2}
# 0.961739 (0.007059) with: {'leaf_size': 9, 'n_neighbors': 10, 'p': 1}
# 0.956322 (0.008533) with: {'leaf_size': 9, 'n_neighbors': 10, 'p': 2}
# 0.954053 (0.006256) with: {'leaf_size': 9, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 9, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005926) with: {'leaf_size': 9, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 9, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.007171) with: {'leaf_size': 9, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 9, 'n_neighbors': 13, 'p': 2}
# 0.950035 (0.008203) with: {'leaf_size': 9, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 9, 'n_neighbors': 14, 'p': 2}
# 0.945318 (0.008709) with: {'leaf_size': 9, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009650) with: {'leaf_size': 9, 'n_neighbors': 15, 'p': 2}
# 0.947589 (0.009604) with: {'leaf_size': 9, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 9, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.008645) with: {'leaf_size': 9, 'n_neighbors': 17, 'p': 1}
# 0.939551 (0.009330) with: {'leaf_size': 9, 'n_neighbors': 17, 'p': 2}
# 0.945494 (0.009718) with: {'leaf_size': 9, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 9, 'n_neighbors': 18, 'p': 2}
# 0.939903 (0.010280) with: {'leaf_size': 9, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 9, 'n_neighbors': 19, 'p': 2}
# 0.942175 (0.009509) with: {'leaf_size': 9, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 9, 'n_neighbors': 20, 'p': 2}
# 0.937631 (0.010010) with: {'leaf_size': 9, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 9, 'n_neighbors': 21, 'p': 2}
# 0.939379 (0.008768) with: {'leaf_size': 9, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 9, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.008382) with: {'leaf_size': 9, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 9, 'n_neighbors': 23, 'p': 2}
# 0.936759 (0.008615) with: {'leaf_size': 9, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 9, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009465) with: {'leaf_size': 9, 'n_neighbors': 25, 'p': 1}
# 0.930817 (0.009642) with: {'leaf_size': 9, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009727) with: {'leaf_size': 9, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 9, 'n_neighbors': 26, 'p': 2}
# 0.930294 (0.008985) with: {'leaf_size': 9, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 9, 'n_neighbors': 27, 'p': 2}
# 0.932043 (0.009724) with: {'leaf_size': 9, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 9, 'n_neighbors': 28, 'p': 2}
# 0.928898 (0.010086) with: {'leaf_size': 9, 'n_neighbors': 29, 'p': 1}
# 0.927148 (0.009922) with: {'leaf_size': 9, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 10, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 10, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 10, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 10, 'n_neighbors': 2, 'p': 2}
# 0.978161 (0.007048) with: {'leaf_size': 10, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 10, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006406) with: {'leaf_size': 10, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 10, 'n_neighbors': 4, 'p': 2}
# 0.971871 (0.006030) with: {'leaf_size': 10, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 10, 'n_neighbors': 5, 'p': 2}
# 0.973095 (0.005961) with: {'leaf_size': 10, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 10, 'n_neighbors': 6, 'p': 2}
# 0.964183 (0.007636) with: {'leaf_size': 10, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 10, 'n_neighbors': 7, 'p': 2}
# 0.967328 (0.007423) with: {'leaf_size': 10, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 10, 'n_neighbors': 8, 'p': 2}
# 0.959642 (0.006883) with: {'leaf_size': 10, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 10, 'n_neighbors': 9, 'p': 2}
# 0.961739 (0.007059) with: {'leaf_size': 10, 'n_neighbors': 10, 'p': 1}
# 0.956322 (0.008533) with: {'leaf_size': 10, 'n_neighbors': 10, 'p': 2}
# 0.954053 (0.006256) with: {'leaf_size': 10, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 10, 'n_neighbors': 11, 'p': 2}
# 0.956149 (0.005926) with: {'leaf_size': 10, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 10, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.007171) with: {'leaf_size': 10, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 10, 'n_neighbors': 13, 'p': 2}
# 0.950035 (0.008203) with: {'leaf_size': 10, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 10, 'n_neighbors': 14, 'p': 2}
# 0.945318 (0.008709) with: {'leaf_size': 10, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009650) with: {'leaf_size': 10, 'n_neighbors': 15, 'p': 2}
# 0.947589 (0.009604) with: {'leaf_size': 10, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 10, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.008645) with: {'leaf_size': 10, 'n_neighbors': 17, 'p': 1}
# 0.939551 (0.009330) with: {'leaf_size': 10, 'n_neighbors': 17, 'p': 2}
# 0.945494 (0.009718) with: {'leaf_size': 10, 'n_neighbors': 18, 'p': 1}
# 0.939726 (0.010058) with: {'leaf_size': 10, 'n_neighbors': 18, 'p': 2}
# 0.939903 (0.010280) with: {'leaf_size': 10, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 10, 'n_neighbors': 19, 'p': 2}
# 0.942175 (0.009509) with: {'leaf_size': 10, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 10, 'n_neighbors': 20, 'p': 2}
# 0.937631 (0.010010) with: {'leaf_size': 10, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 10, 'n_neighbors': 21, 'p': 2}
# 0.939379 (0.008768) with: {'leaf_size': 10, 'n_neighbors': 22, 'p': 1}
# 0.935709 (0.008411) with: {'leaf_size': 10, 'n_neighbors': 22, 'p': 2}
# 0.936409 (0.008382) with: {'leaf_size': 10, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 10, 'n_neighbors': 23, 'p': 2}
# 0.936759 (0.008615) with: {'leaf_size': 10, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 10, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009465) with: {'leaf_size': 10, 'n_neighbors': 25, 'p': 1}
# 0.930817 (0.009642) with: {'leaf_size': 10, 'n_neighbors': 25, 'p': 2}
# 0.934488 (0.009727) with: {'leaf_size': 10, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 10, 'n_neighbors': 26, 'p': 2}
# 0.930294 (0.008985) with: {'leaf_size': 10, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 10, 'n_neighbors': 27, 'p': 2}
# 0.932043 (0.009724) with: {'leaf_size': 10, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 10, 'n_neighbors': 28, 'p': 2}
# 0.928898 (0.010086) with: {'leaf_size': 10, 'n_neighbors': 29, 'p': 1}
# 0.927148 (0.009922) with: {'leaf_size': 10, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 11, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 11, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 11, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 11, 'n_neighbors': 2, 'p': 2}
# 0.977986 (0.007088) with: {'leaf_size': 11, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 11, 'n_neighbors': 3, 'p': 2}
# 0.981306 (0.006254) with: {'leaf_size': 11, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 11, 'n_neighbors': 4, 'p': 2}
# 0.971522 (0.006307) with: {'leaf_size': 11, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 11, 'n_neighbors': 5, 'p': 2}
# 0.972746 (0.005536) with: {'leaf_size': 11, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 11, 'n_neighbors': 6, 'p': 2}
# 0.963659 (0.007034) with: {'leaf_size': 11, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 11, 'n_neighbors': 7, 'p': 2}
# 0.967503 (0.006962) with: {'leaf_size': 11, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 11, 'n_neighbors': 8, 'p': 2}
# 0.959118 (0.006917) with: {'leaf_size': 11, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 11, 'n_neighbors': 9, 'p': 2}
# 0.961390 (0.007103) with: {'leaf_size': 11, 'n_neighbors': 10, 'p': 1}
# 0.956497 (0.008549) with: {'leaf_size': 11, 'n_neighbors': 10, 'p': 2}
# 0.954402 (0.005876) with: {'leaf_size': 11, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 11, 'n_neighbors': 11, 'p': 2}
# 0.956673 (0.005840) with: {'leaf_size': 11, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 11, 'n_neighbors': 12, 'p': 2}
# 0.950034 (0.007790) with: {'leaf_size': 11, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 11, 'n_neighbors': 13, 'p': 2}
# 0.949161 (0.008688) with: {'leaf_size': 11, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 11, 'n_neighbors': 14, 'p': 2}
# 0.945143 (0.008535) with: {'leaf_size': 11, 'n_neighbors': 15, 'p': 1}
# 0.942695 (0.009483) with: {'leaf_size': 11, 'n_neighbors': 15, 'p': 2}
# 0.946891 (0.009384) with: {'leaf_size': 11, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 11, 'n_neighbors': 16, 'p': 2}
# 0.943047 (0.009318) with: {'leaf_size': 11, 'n_neighbors': 17, 'p': 1}
# 0.939900 (0.009397) with: {'leaf_size': 11, 'n_neighbors': 17, 'p': 2}
# 0.945668 (0.009989) with: {'leaf_size': 11, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.010116) with: {'leaf_size': 11, 'n_neighbors': 18, 'p': 2}
# 0.940602 (0.010061) with: {'leaf_size': 11, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 11, 'n_neighbors': 19, 'p': 2}
# 0.942350 (0.009397) with: {'leaf_size': 11, 'n_neighbors': 20, 'p': 1}
# 0.938854 (0.007898) with: {'leaf_size': 11, 'n_neighbors': 20, 'p': 2}
# 0.937805 (0.009800) with: {'leaf_size': 11, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 11, 'n_neighbors': 21, 'p': 2}
# 0.938679 (0.009060) with: {'leaf_size': 11, 'n_neighbors': 22, 'p': 1}
# 0.935535 (0.008433) with: {'leaf_size': 11, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.009081) with: {'leaf_size': 11, 'n_neighbors': 23, 'p': 1}
# 0.933089 (0.008772) with: {'leaf_size': 11, 'n_neighbors': 23, 'p': 2}
# 0.936235 (0.008978) with: {'leaf_size': 11, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 11, 'n_neighbors': 24, 'p': 2}
# 0.933440 (0.009734) with: {'leaf_size': 11, 'n_neighbors': 25, 'p': 1}
# 0.930992 (0.009739) with: {'leaf_size': 11, 'n_neighbors': 25, 'p': 2}
# 0.933614 (0.009625) with: {'leaf_size': 11, 'n_neighbors': 26, 'p': 1}
# 0.931516 (0.009908) with: {'leaf_size': 11, 'n_neighbors': 26, 'p': 2}
# 0.930644 (0.009435) with: {'leaf_size': 11, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 11, 'n_neighbors': 27, 'p': 2}
# 0.931519 (0.009382) with: {'leaf_size': 11, 'n_neighbors': 28, 'p': 1}
# 0.929595 (0.010156) with: {'leaf_size': 11, 'n_neighbors': 28, 'p': 2}
# 0.929072 (0.009501) with: {'leaf_size': 11, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 11, 'n_neighbors': 29, 'p': 2}
# 0.989867 (0.003565) with: {'leaf_size': 12, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 12, 'n_neighbors': 1, 'p': 2}
# 0.991089 (0.003620) with: {'leaf_size': 12, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 12, 'n_neighbors': 2, 'p': 2}
# 0.977986 (0.007088) with: {'leaf_size': 12, 'n_neighbors': 3, 'p': 1}
# 0.977811 (0.006950) with: {'leaf_size': 12, 'n_neighbors': 3, 'p': 2}
# 0.981306 (0.006254) with: {'leaf_size': 12, 'n_neighbors': 4, 'p': 1}
# 0.977287 (0.007499) with: {'leaf_size': 12, 'n_neighbors': 4, 'p': 2}
# 0.971522 (0.006307) with: {'leaf_size': 12, 'n_neighbors': 5, 'p': 1}
# 0.968551 (0.008950) with: {'leaf_size': 12, 'n_neighbors': 5, 'p': 2}
# 0.972746 (0.005536) with: {'leaf_size': 12, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 12, 'n_neighbors': 6, 'p': 2}
# 0.963659 (0.007034) with: {'leaf_size': 12, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 12, 'n_neighbors': 7, 'p': 2}
# 0.967503 (0.006962) with: {'leaf_size': 12, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 12, 'n_neighbors': 8, 'p': 2}
# 0.959118 (0.006917) with: {'leaf_size': 12, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 12, 'n_neighbors': 9, 'p': 2}
# 0.961390 (0.007103) with: {'leaf_size': 12, 'n_neighbors': 10, 'p': 1}
# 0.956497 (0.008549) with: {'leaf_size': 12, 'n_neighbors': 10, 'p': 2}
# 0.954402 (0.005876) with: {'leaf_size': 12, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 12, 'n_neighbors': 11, 'p': 2}
# 0.956673 (0.005840) with: {'leaf_size': 12, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 12, 'n_neighbors': 12, 'p': 2}
# 0.950034 (0.007790) with: {'leaf_size': 12, 'n_neighbors': 13, 'p': 1}
# 0.947760 (0.010457) with: {'leaf_size': 12, 'n_neighbors': 13, 'p': 2}
# 0.949161 (0.008688) with: {'leaf_size': 12, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 12, 'n_neighbors': 14, 'p': 2}
# 0.945143 (0.008535) with: {'leaf_size': 12, 'n_neighbors': 15, 'p': 1}
# 0.942695 (0.009483) with: {'leaf_size': 12, 'n_neighbors': 15, 'p': 2}
# 0.946891 (0.009384) with: {'leaf_size': 12, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 12, 'n_neighbors': 16, 'p': 2}
# 0.943047 (0.009318) with: {'leaf_size': 12, 'n_neighbors': 17, 'p': 1}
# 0.939900 (0.009397) with: {'leaf_size': 12, 'n_neighbors': 17, 'p': 2}
# 0.945668 (0.009989) with: {'leaf_size': 12, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.010116) with: {'leaf_size': 12, 'n_neighbors': 18, 'p': 2}
# 0.940602 (0.010061) with: {'leaf_size': 12, 'n_neighbors': 19, 'p': 1}
# 0.937105 (0.008889) with: {'leaf_size': 12, 'n_neighbors': 19, 'p': 2}
# 0.942350 (0.009397) with: {'leaf_size': 12, 'n_neighbors': 20, 'p': 1}
# 0.938854 (0.007898) with: {'leaf_size': 12, 'n_neighbors': 20, 'p': 2}
# 0.937805 (0.009800) with: {'leaf_size': 12, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 12, 'n_neighbors': 21, 'p': 2}
# 0.938679 (0.009060) with: {'leaf_size': 12, 'n_neighbors': 22, 'p': 1}
# 0.935535 (0.008433) with: {'leaf_size': 12, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.009081) with: {'leaf_size': 12, 'n_neighbors': 23, 'p': 1}
# 0.933089 (0.008772) with: {'leaf_size': 12, 'n_neighbors': 23, 'p': 2}
# 0.936235 (0.008978) with: {'leaf_size': 12, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 12, 'n_neighbors': 24, 'p': 2}
# ...
# 0.959117 (0.007755) with: {'leaf_size': 46, 'n_neighbors': 7, 'p': 2}
# 0.967154 (0.006538) with: {'leaf_size': 46, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 46, 'n_neighbors': 8, 'p': 2}
# 0.958944 (0.007509) with: {'leaf_size': 46, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 46, 'n_neighbors': 9, 'p': 2}
# 0.961564 (0.007082) with: {'leaf_size': 46, 'n_neighbors': 10, 'p': 1}
# 0.956846 (0.008427) with: {'leaf_size': 46, 'n_neighbors': 10, 'p': 2}
# 0.954228 (0.006194) with: {'leaf_size': 46, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 46, 'n_neighbors': 11, 'p': 2}
# 0.955974 (0.005736) with: {'leaf_size': 46, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 46, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.008167) with: {'leaf_size': 46, 'n_neighbors': 13, 'p': 1}
# 0.947585 (0.010147) with: {'leaf_size': 46, 'n_neighbors': 13, 'p': 2}
# 0.950385 (0.008532) with: {'leaf_size': 46, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 46, 'n_neighbors': 14, 'p': 2}
# 0.945143 (0.008571) with: {'leaf_size': 46, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009428) with: {'leaf_size': 46, 'n_neighbors': 15, 'p': 2}
# 0.946716 (0.009289) with: {'leaf_size': 46, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 46, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.009255) with: {'leaf_size': 46, 'n_neighbors': 17, 'p': 1}
# 0.939726 (0.009462) with: {'leaf_size': 46, 'n_neighbors': 17, 'p': 2}
# 0.944271 (0.009673) with: {'leaf_size': 46, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.010116) with: {'leaf_size': 46, 'n_neighbors': 18, 'p': 2}
# 0.940427 (0.009801) with: {'leaf_size': 46, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 46, 'n_neighbors': 19, 'p': 2}
# 0.942000 (0.009228) with: {'leaf_size': 46, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 46, 'n_neighbors': 20, 'p': 2}
# 0.937107 (0.009793) with: {'leaf_size': 46, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 46, 'n_neighbors': 21, 'p': 2}
# 0.939028 (0.008361) with: {'leaf_size': 46, 'n_neighbors': 22, 'p': 1}
# 0.935535 (0.008433) with: {'leaf_size': 46, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.009604) with: {'leaf_size': 46, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 46, 'n_neighbors': 23, 'p': 2}
# 0.937108 (0.008554) with: {'leaf_size': 46, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 46, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009500) with: {'leaf_size': 46, 'n_neighbors': 25, 'p': 1}
# 0.930643 (0.009699) with: {'leaf_size': 46, 'n_neighbors': 25, 'p': 2}
# 0.934138 (0.009341) with: {'leaf_size': 46, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 46, 'n_neighbors': 26, 'p': 2}
# 0.930993 (0.009279) with: {'leaf_size': 46, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 46, 'n_neighbors': 27, 'p': 2}
# 0.931169 (0.008899) with: {'leaf_size': 46, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 46, 'n_neighbors': 28, 'p': 2}
# 0.929072 (0.009971) with: {'leaf_size': 46, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 46, 'n_neighbors': 29, 'p': 2}
# 0.989692 (0.003535) with: {'leaf_size': 47, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 47, 'n_neighbors': 1, 'p': 2}
# 0.991264 (0.003748) with: {'leaf_size': 47, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 47, 'n_neighbors': 2, 'p': 2}
# 0.977812 (0.007376) with: {'leaf_size': 47, 'n_neighbors': 3, 'p': 1}
# 0.977636 (0.007112) with: {'leaf_size': 47, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006454) with: {'leaf_size': 47, 'n_neighbors': 4, 'p': 1}
# 0.977112 (0.007677) with: {'leaf_size': 47, 'n_neighbors': 4, 'p': 2}
# 0.971697 (0.006047) with: {'leaf_size': 47, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 47, 'n_neighbors': 5, 'p': 2}
# 0.972920 (0.006117) with: {'leaf_size': 47, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 47, 'n_neighbors': 6, 'p': 2}
# 0.963484 (0.007319) with: {'leaf_size': 47, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 47, 'n_neighbors': 7, 'p': 2}
# 0.967154 (0.006538) with: {'leaf_size': 47, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 47, 'n_neighbors': 8, 'p': 2}
# 0.958944 (0.007509) with: {'leaf_size': 47, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 47, 'n_neighbors': 9, 'p': 2}
# 0.961564 (0.007082) with: {'leaf_size': 47, 'n_neighbors': 10, 'p': 1}
# 0.956846 (0.008427) with: {'leaf_size': 47, 'n_neighbors': 10, 'p': 2}
# 0.954228 (0.006194) with: {'leaf_size': 47, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 47, 'n_neighbors': 11, 'p': 2}
# 0.955974 (0.005736) with: {'leaf_size': 47, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 47, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.008167) with: {'leaf_size': 47, 'n_neighbors': 13, 'p': 1}
# 0.947585 (0.010147) with: {'leaf_size': 47, 'n_neighbors': 13, 'p': 2}
# 0.950385 (0.008532) with: {'leaf_size': 47, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 47, 'n_neighbors': 14, 'p': 2}
# 0.945143 (0.008571) with: {'leaf_size': 47, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009428) with: {'leaf_size': 47, 'n_neighbors': 15, 'p': 2}
# 0.946716 (0.009289) with: {'leaf_size': 47, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 47, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.009255) with: {'leaf_size': 47, 'n_neighbors': 17, 'p': 1}
# 0.939726 (0.009462) with: {'leaf_size': 47, 'n_neighbors': 17, 'p': 2}
# 0.944271 (0.009673) with: {'leaf_size': 47, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.010116) with: {'leaf_size': 47, 'n_neighbors': 18, 'p': 2}
# 0.940427 (0.009801) with: {'leaf_size': 47, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 47, 'n_neighbors': 19, 'p': 2}
# 0.942000 (0.009228) with: {'leaf_size': 47, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 47, 'n_neighbors': 20, 'p': 2}
# 0.937107 (0.009793) with: {'leaf_size': 47, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 47, 'n_neighbors': 21, 'p': 2}
# 0.939028 (0.008361) with: {'leaf_size': 47, 'n_neighbors': 22, 'p': 1}
# 0.935535 (0.008433) with: {'leaf_size': 47, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.009604) with: {'leaf_size': 47, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 47, 'n_neighbors': 23, 'p': 2}
# 0.937108 (0.008554) with: {'leaf_size': 47, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 47, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009500) with: {'leaf_size': 47, 'n_neighbors': 25, 'p': 1}
# 0.930643 (0.009699) with: {'leaf_size': 47, 'n_neighbors': 25, 'p': 2}
# 0.934138 (0.009341) with: {'leaf_size': 47, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 47, 'n_neighbors': 26, 'p': 2}
# 0.930993 (0.009279) with: {'leaf_size': 47, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 47, 'n_neighbors': 27, 'p': 2}
# 0.931169 (0.008899) with: {'leaf_size': 47, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 47, 'n_neighbors': 28, 'p': 2}
# 0.929072 (0.009971) with: {'leaf_size': 47, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 47, 'n_neighbors': 29, 'p': 2}
# 0.989692 (0.003535) with: {'leaf_size': 48, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 48, 'n_neighbors': 1, 'p': 2}
# 0.991264 (0.003748) with: {'leaf_size': 48, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 48, 'n_neighbors': 2, 'p': 2}
# 0.977812 (0.007376) with: {'leaf_size': 48, 'n_neighbors': 3, 'p': 1}
# 0.977636 (0.007112) with: {'leaf_size': 48, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006454) with: {'leaf_size': 48, 'n_neighbors': 4, 'p': 1}
# 0.977112 (0.007677) with: {'leaf_size': 48, 'n_neighbors': 4, 'p': 2}
# 0.971697 (0.006047) with: {'leaf_size': 48, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 48, 'n_neighbors': 5, 'p': 2}
# 0.972920 (0.006117) with: {'leaf_size': 48, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 48, 'n_neighbors': 6, 'p': 2}
# 0.963484 (0.007319) with: {'leaf_size': 48, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 48, 'n_neighbors': 7, 'p': 2}
# 0.967154 (0.006538) with: {'leaf_size': 48, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 48, 'n_neighbors': 8, 'p': 2}
# 0.958944 (0.007509) with: {'leaf_size': 48, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 48, 'n_neighbors': 9, 'p': 2}
# 0.961564 (0.007082) with: {'leaf_size': 48, 'n_neighbors': 10, 'p': 1}
# 0.956846 (0.008427) with: {'leaf_size': 48, 'n_neighbors': 10, 'p': 2}
# 0.954228 (0.006194) with: {'leaf_size': 48, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 48, 'n_neighbors': 11, 'p': 2}
# 0.955974 (0.005736) with: {'leaf_size': 48, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 48, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.008167) with: {'leaf_size': 48, 'n_neighbors': 13, 'p': 1}
# 0.947585 (0.010147) with: {'leaf_size': 48, 'n_neighbors': 13, 'p': 2}
# 0.950385 (0.008532) with: {'leaf_size': 48, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 48, 'n_neighbors': 14, 'p': 2}
# 0.945143 (0.008571) with: {'leaf_size': 48, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009428) with: {'leaf_size': 48, 'n_neighbors': 15, 'p': 2}
# 0.946716 (0.009289) with: {'leaf_size': 48, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 48, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.009255) with: {'leaf_size': 48, 'n_neighbors': 17, 'p': 1}
# 0.939726 (0.009462) with: {'leaf_size': 48, 'n_neighbors': 17, 'p': 2}
# 0.944271 (0.009673) with: {'leaf_size': 48, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.010116) with: {'leaf_size': 48, 'n_neighbors': 18, 'p': 2}
# 0.940427 (0.009801) with: {'leaf_size': 48, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 48, 'n_neighbors': 19, 'p': 2}
# 0.942000 (0.009228) with: {'leaf_size': 48, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 48, 'n_neighbors': 20, 'p': 2}
# 0.937107 (0.009793) with: {'leaf_size': 48, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 48, 'n_neighbors': 21, 'p': 2}
# 0.939028 (0.008361) with: {'leaf_size': 48, 'n_neighbors': 22, 'p': 1}
# 0.935535 (0.008433) with: {'leaf_size': 48, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.009604) with: {'leaf_size': 48, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 48, 'n_neighbors': 23, 'p': 2}
# 0.937108 (0.008554) with: {'leaf_size': 48, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 48, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009500) with: {'leaf_size': 48, 'n_neighbors': 25, 'p': 1}
# 0.930643 (0.009699) with: {'leaf_size': 48, 'n_neighbors': 25, 'p': 2}
# 0.934138 (0.009341) with: {'leaf_size': 48, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 48, 'n_neighbors': 26, 'p': 2}
# 0.930993 (0.009279) with: {'leaf_size': 48, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 48, 'n_neighbors': 27, 'p': 2}
# 0.931169 (0.008899) with: {'leaf_size': 48, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 48, 'n_neighbors': 28, 'p': 2}
# 0.929072 (0.009971) with: {'leaf_size': 48, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 48, 'n_neighbors': 29, 'p': 2}
# 0.989692 (0.003535) with: {'leaf_size': 49, 'n_neighbors': 1, 'p': 1}
# 0.991090 (0.004651) with: {'leaf_size': 49, 'n_neighbors': 1, 'p': 2}
# 0.991264 (0.003748) with: {'leaf_size': 49, 'n_neighbors': 2, 'p': 1}
# 0.990217 (0.004696) with: {'leaf_size': 49, 'n_neighbors': 2, 'p': 2}
# 0.977812 (0.007376) with: {'leaf_size': 49, 'n_neighbors': 3, 'p': 1}
# 0.977636 (0.007112) with: {'leaf_size': 49, 'n_neighbors': 3, 'p': 2}
# 0.981481 (0.006454) with: {'leaf_size': 49, 'n_neighbors': 4, 'p': 1}
# 0.977112 (0.007677) with: {'leaf_size': 49, 'n_neighbors': 4, 'p': 2}
# 0.971697 (0.006047) with: {'leaf_size': 49, 'n_neighbors': 5, 'p': 1}
# 0.968376 (0.008895) with: {'leaf_size': 49, 'n_neighbors': 5, 'p': 2}
# 0.972920 (0.006117) with: {'leaf_size': 49, 'n_neighbors': 6, 'p': 1}
# 0.968204 (0.007440) with: {'leaf_size': 49, 'n_neighbors': 6, 'p': 2}
# 0.963484 (0.007319) with: {'leaf_size': 49, 'n_neighbors': 7, 'p': 1}
# 0.959117 (0.007755) with: {'leaf_size': 49, 'n_neighbors': 7, 'p': 2}
# 0.967154 (0.006538) with: {'leaf_size': 49, 'n_neighbors': 8, 'p': 1}
# 0.960165 (0.009049) with: {'leaf_size': 49, 'n_neighbors': 8, 'p': 2}
# 0.958944 (0.007509) with: {'leaf_size': 49, 'n_neighbors': 9, 'p': 1}
# 0.954226 (0.008597) with: {'leaf_size': 49, 'n_neighbors': 9, 'p': 2}
# 0.961564 (0.007082) with: {'leaf_size': 49, 'n_neighbors': 10, 'p': 1}
# 0.956846 (0.008427) with: {'leaf_size': 49, 'n_neighbors': 10, 'p': 2}
# 0.954228 (0.006194) with: {'leaf_size': 49, 'n_neighbors': 11, 'p': 1}
# 0.950905 (0.009539) with: {'leaf_size': 49, 'n_neighbors': 11, 'p': 2}
# 0.955974 (0.005736) with: {'leaf_size': 49, 'n_neighbors': 12, 'p': 1}
# 0.951604 (0.009230) with: {'leaf_size': 49, 'n_neighbors': 12, 'p': 2}
# 0.949860 (0.008167) with: {'leaf_size': 49, 'n_neighbors': 13, 'p': 1}
# 0.947585 (0.010147) with: {'leaf_size': 49, 'n_neighbors': 13, 'p': 2}
# 0.950385 (0.008532) with: {'leaf_size': 49, 'n_neighbors': 14, 'p': 1}
# 0.947936 (0.009951) with: {'leaf_size': 49, 'n_neighbors': 14, 'p': 2}
# 0.945143 (0.008571) with: {'leaf_size': 49, 'n_neighbors': 15, 'p': 1}
# 0.942870 (0.009428) with: {'leaf_size': 49, 'n_neighbors': 15, 'p': 2}
# 0.946716 (0.009289) with: {'leaf_size': 49, 'n_neighbors': 16, 'p': 1}
# 0.944268 (0.010032) with: {'leaf_size': 49, 'n_neighbors': 16, 'p': 2}
# 0.942174 (0.009255) with: {'leaf_size': 49, 'n_neighbors': 17, 'p': 1}
# 0.939726 (0.009462) with: {'leaf_size': 49, 'n_neighbors': 17, 'p': 2}
# 0.944271 (0.009673) with: {'leaf_size': 49, 'n_neighbors': 18, 'p': 1}
# 0.939551 (0.010116) with: {'leaf_size': 49, 'n_neighbors': 18, 'p': 2}
# 0.940427 (0.009801) with: {'leaf_size': 49, 'n_neighbors': 19, 'p': 1}
# 0.936931 (0.008662) with: {'leaf_size': 49, 'n_neighbors': 19, 'p': 2}
# 0.942000 (0.009228) with: {'leaf_size': 49, 'n_neighbors': 20, 'p': 1}
# 0.939028 (0.007955) with: {'leaf_size': 49, 'n_neighbors': 20, 'p': 2}
# 0.937107 (0.009793) with: {'leaf_size': 49, 'n_neighbors': 21, 'p': 1}
# 0.934487 (0.007822) with: {'leaf_size': 49, 'n_neighbors': 21, 'p': 2}
# 0.939028 (0.008361) with: {'leaf_size': 49, 'n_neighbors': 22, 'p': 1}
# 0.935535 (0.008433) with: {'leaf_size': 49, 'n_neighbors': 22, 'p': 2}
# 0.936234 (0.009604) with: {'leaf_size': 49, 'n_neighbors': 23, 'p': 1}
# 0.932914 (0.008948) with: {'leaf_size': 49, 'n_neighbors': 23, 'p': 2}
# 0.937108 (0.008554) with: {'leaf_size': 49, 'n_neighbors': 24, 'p': 1}
# 0.933613 (0.009571) with: {'leaf_size': 49, 'n_neighbors': 24, 'p': 2}
# 0.933614 (0.009500) with: {'leaf_size': 49, 'n_neighbors': 25, 'p': 1}
# 0.930643 (0.009699) with: {'leaf_size': 49, 'n_neighbors': 25, 'p': 2}
# 0.934138 (0.009341) with: {'leaf_size': 49, 'n_neighbors': 26, 'p': 1}
# 0.931342 (0.009697) with: {'leaf_size': 49, 'n_neighbors': 26, 'p': 2}
# 0.930993 (0.009279) with: {'leaf_size': 49, 'n_neighbors': 27, 'p': 1}
# 0.928023 (0.009562) with: {'leaf_size': 49, 'n_neighbors': 27, 'p': 2}
# 0.931169 (0.008899) with: {'leaf_size': 49, 'n_neighbors': 28, 'p': 1}
# 0.929420 (0.009917) with: {'leaf_size': 49, 'n_neighbors': 28, 'p': 2}
# 0.929072 (0.009971) with: {'leaf_size': 49, 'n_neighbors': 29, 'p': 1}
# 0.926799 (0.009683) with: {'leaf_size': 49, 'n_neighbors': 29, 'p': 2}
# -----------------------------------------------------------
#
# Best Accuracy: 0.991265 using {'leaf_size': 3, 'n_neighbors': 1, 'p': 2}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00       615
#          1.0       0.99      1.00      1.00       817
#
#     accuracy                           1.00      1432
#    macro avg       1.00      1.00      1.00      1432
# weighted avg       1.00      1.00      1.00      1432

# %% [markdown]
# #### Logistic Regression

# %%
hyperTuning(LogisticRegression(), 
            dict(C = np.logspace(-4, 4, 20), max_iter = [1000, 2500, 5000]),
            X2_train, y2_train, X2_test, y2_test)
# Out:
# 0.851328 (0.011865) with: {'C': 0.0001, 'max_iter': 1000}
# 0.851328 (0.011865) with: {'C': 0.0001, 'max_iter': 2500}
# 0.851328 (0.011865) with: {'C': 0.0001, 'max_iter': 5000}
# 0.854996 (0.012066) with: {'C': 0.00026366508987303583, 'max_iter': 1000}
# 0.854996 (0.012066) with: {'C': 0.00026366508987303583, 'max_iter': 2500}
# 0.854996 (0.012066) with: {'C': 0.00026366508987303583, 'max_iter': 5000}
# 0.865653 (0.011181) with: {'C': 0.0006951927961775605, 'max_iter': 1000}
# 0.865653 (0.011181) with: {'C': 0.0006951927961775605, 'max_iter': 2500}
# 0.865653 (0.011181) with: {'C': 0.0006951927961775605, 'max_iter': 5000}
# 0.874039 (0.013272) with: {'C': 0.0018329807108324356, 'max_iter': 1000}
# 0.874039 (0.013272) with: {'C': 0.0018329807108324356, 'max_iter': 2500}
# 0.874039 (0.013272) with: {'C': 0.0018329807108324356, 'max_iter': 5000}
# 0.884348 (0.011442) with: {'C': 0.004832930238571752, 'max_iter': 1000}
# 0.884348 (0.011442) with: {'C': 0.004832930238571752, 'max_iter': 2500}
# 0.884348 (0.011442) with: {'C': 0.004832930238571752, 'max_iter': 5000}
# 0.898849 (0.012861) with: {'C': 0.012742749857031334, 'max_iter': 1000}
# 0.898849 (0.012861) with: {'C': 0.012742749857031334, 'max_iter': 2500}
# 0.898849 (0.012861) with: {'C': 0.012742749857031334, 'max_iter': 5000}
# 0.903568 (0.016026) with: {'C': 0.03359818286283781, 'max_iter': 1000}
# 0.903393 (0.016795) with: {'C': 0.03359818286283781, 'max_iter': 2500}
# 0.903393 (0.016795) with: {'C': 0.03359818286283781, 'max_iter': 5000}
# 0.906710 (0.016597) with: {'C': 0.08858667904100823, 'max_iter': 1000}
# 0.907760 (0.017528) with: {'C': 0.08858667904100823, 'max_iter': 2500}
# 0.907760 (0.017528) with: {'C': 0.08858667904100823, 'max_iter': 5000}
# 0.907236 (0.016904) with: {'C': 0.23357214690901212, 'max_iter': 1000}
# 0.908983 (0.015265) with: {'C': 0.23357214690901212, 'max_iter': 2500}
# 0.908983 (0.015265) with: {'C': 0.23357214690901212, 'max_iter': 5000}
# 0.907059 (0.016066) with: {'C': 0.615848211066026, 'max_iter': 1000}
# 0.908982 (0.015723) with: {'C': 0.615848211066026, 'max_iter': 2500}
# 0.908982 (0.015723) with: {'C': 0.615848211066026, 'max_iter': 5000}
# 0.907585 (0.015606) with: {'C': 1.623776739188721, 'max_iter': 1000}
# 0.909681 (0.016456) with: {'C': 1.623776739188721, 'max_iter': 2500}
# 0.909681 (0.016456) with: {'C': 1.623776739188721, 'max_iter': 5000}
# 0.905662 (0.015835) with: {'C': 4.281332398719396, 'max_iter': 1000}
# 0.908982 (0.017821) with: {'C': 4.281332398719396, 'max_iter': 2500}
# 0.908982 (0.017821) with: {'C': 4.281332398719396, 'max_iter': 5000}
# 0.906886 (0.016026) with: {'C': 11.288378916846883, 'max_iter': 1000}
# 0.909157 (0.015890) with: {'C': 11.288378916846883, 'max_iter': 2500}
# 0.909157 (0.015890) with: {'C': 11.288378916846883, 'max_iter': 5000}
# 0.905488 (0.015709) with: {'C': 29.763514416313132, 'max_iter': 1000}
# 0.908982 (0.016944) with: {'C': 29.763514416313132, 'max_iter': 2500}
# 0.908982 (0.016944) with: {'C': 29.763514416313132, 'max_iter': 5000}
# 0.907759 (0.016419) with: {'C': 78.47599703514607, 'max_iter': 1000}
# 0.908982 (0.016687) with: {'C': 78.47599703514607, 'max_iter': 2500}
# 0.908982 (0.016687) with: {'C': 78.47599703514607, 'max_iter': 5000}
# 0.906361 (0.015858) with: {'C': 206.913808111479, 'max_iter': 1000}
# 0.908982 (0.016538) with: {'C': 206.913808111479, 'max_iter': 2500}
# 0.908982 (0.016538) with: {'C': 206.913808111479, 'max_iter': 5000}
# 0.906361 (0.016395) with: {'C': 545.5594781168514, 'max_iter': 1000}
# 0.908982 (0.016390) with: {'C': 545.5594781168514, 'max_iter': 2500}
# 0.908982 (0.016390) with: {'C': 545.5594781168514, 'max_iter': 5000}
# 0.907060 (0.015578) with: {'C': 1438.44988828766, 'max_iter': 1000}
# 0.908458 (0.016793) with: {'C': 1438.44988828766, 'max_iter': 2500}
# 0.908458 (0.016793) with: {'C': 1438.44988828766, 'max_iter': 5000}
# 0.907236 (0.015723) with: {'C': 3792.690190732246, 'max_iter': 1000}
# 0.909332 (0.016316) with: {'C': 3792.690190732246, 'max_iter': 2500}
# 0.909332 (0.016316) with: {'C': 3792.690190732246, 'max_iter': 5000}
# 0.907411 (0.015865) with: {'C': 10000.0, 'max_iter': 1000}
# 0.908632 (0.017816) with: {'C': 10000.0, 'max_iter': 2500}
# 0.908632 (0.017816) with: {'C': 10000.0, 'max_iter': 5000}
# -----------------------------------------------------------
#
# Best Accuracy: 0.909681 using {'C': 1.623776739188721, 'max_iter': 2500}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.87      0.89       615
#          1.0       0.91      0.94      0.92       817
#
#     accuracy                           0.91      1432
#    macro avg       0.91      0.91      0.91      1432
# weighted avg       0.91      0.91      0.91      1432

# %% [markdown]
# #### Random Forest

# %%
hyperTuning(RandomForestClassifier(), dict(n_estimators = [10, 100, 1000], max_features = ['sqrt', 'log2']),
            X2_train, y2_train, X2_test, y2_test)
# Out:
# 0.986900 (0.005189) with: {'max_features': 'sqrt', 'n_estimators': 10}
# 0.988121 (0.003728) with: {'max_features': 'sqrt', 'n_estimators': 100}
# 0.988121 (0.004471) with: {'max_features': 'sqrt', 'n_estimators': 1000}
# 0.987772 (0.005236) with: {'max_features': 'log2', 'n_estimators': 10}
# 0.988820 (0.004218) with: {'max_features': 'log2', 'n_estimators': 100}
# 0.987947 (0.004306) with: {'max_features': 'log2', 'n_estimators': 1000}
# -----------------------------------------------------------
#
# Best Accuracy: 0.988820 using {'max_features': 'log2', 'n_estimators': 100}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99       615
#          1.0       0.99      1.00      0.99       817
#
#     accuracy                           0.99      1432
#    macro avg       0.99      0.99      0.99      1432
# weighted avg       0.99      0.99      0.99      1432

# %% [markdown]
# ### ROC Curve After Tuning

# %%
classifiers = [LogisticRegression(C=1.623776739188721, max_iter=2500, random_state=RANSTA),
               KNeighborsClassifier(leaf_size=3, n_neighbors=1, p=2), 
               RandomForestClassifier(max_features='log2', n_estimators=100, random_state=RANSTA)]

# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    model = cls.fit(X2_train, y2_train)
    yproba = model.predict_proba(X2_test)[::,1]
    
    fpr, tpr, _ = roc_curve(y2_test,  yproba)
    auc = roc_auc_score(y2_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)

fig = plt.figure(figsize=(8,6))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()
